# %%
from game_of_life import GameOfLife

# %%
gol = GameOfLife(
    n_rows=8,
    n_cols=8,
    density_value=0.2,
    n_iterations=25,
    pause_len=1
)
gol.start_new_game
# Out:
# ITERATION 1/25
# +---+---+---+---+---+---+---+---+
# |   |   |   | ■ |   |   | ■ |   |
# +---+---+---+---+---+---+---+---+
# |   |   |   | ■ |   |   | ■ |   |
# +---+---+---+---+---+---+---+---+
# |   |   |   | ■ |   |   | ■ |   |
# +---+---+---+---+---+---+---+---+
# |   |   |   |   |   |   | ■ |   |
# +---+---+---+---+---+---+---+---+
# | ■ |   |   |   |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# | ■ |   |   |   | ■ |   |   |   |
# +---+---+---+---+---+---+---+---+
# |   |   | ■ |   |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# |   | ■ |   |   |   | ■ |   |   |
# +---+---+---+---+---+---+---+---+
#
#
#
# ITERATION 2/25
# +---+---+---+---+---+---+---+---+
# |   |   | ■ |   | ■ | ■ | ■ |   |
# +---+---+---+---+---+---+---+---+
# |   |   | ■ | ■ | ■ | ■ | ■ | ■ |
# +---+---+---+---+---+---+---+---+
# |   |   |   |   |   | ■ | ■ | ■ |
# +---+---+---+---+---+---+---+---+
# |   |   |   |   |   |   |   | ■ |
# +---+---+---+---+---+---+---+---+
# ...

# %%
gol = GameOfLife(
    n_rows=8,
    n_cols=8,
    density_value=0.2,
    n_iterations=25,
    pause_len=1
)
gol.start_new_game
# Out:
# ITERATION 1/25
# +---+---+---+---+---+---+---+---+
# |   |   |   |   |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# |   |   |   | ■ | ■ |   |   |   |
# +---+---+---+---+---+---+---+---+
# |   |   | ■ |   |   |   |   | ■ |
# +---+---+---+---+---+---+---+---+
# |   | ■ |   |   |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# | ■ |   | ■ |   | ■ | ■ |   |   |
# +---+---+---+---+---+---+---+---+
# |   |   | ■ |   |   | ■ |   |   |
# +---+---+---+---+---+---+---+---+
# |   |   |   | ■ |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# | ■ |   | ■ |   | ■ | ■ |   |   |
# +---+---+---+---+---+---+---+---+
#
#
#
# ITERATION 2/25
# +---+---+---+---+---+---+---+---+
# |   |   |   |   |   | ■ |   |   |
# +---+---+---+---+---+---+---+---+
# |   |   |   | ■ |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# |   |   | ■ | ■ |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# | ■ | ■ | ■ | ■ |   |   |   |   |
# +---+---+---+---+---+---+---+---+
# ...
